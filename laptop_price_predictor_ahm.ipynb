# %%
#import libraries
import numpy as np
import pandas as pd

# %%
#read and show data
df = pd.read_csv('laptop_data_new.csv')
df.head(10)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5           5    Acer   Notebook    15.6                            1366x768
# 6           6   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7           7   Apple  Ultrabook    13.3                            1440x900
# 8           8    Asus  Ultrabook    14.0                   Full HD 1920x1080
# 9           9    Acer  Ultrabook    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
# 5     AMD A9-Series 9420 3GHz   4GB            500GB HDD
# 6        Intel Core i7 2.2GHz  16GB  256GB Flash Storage
# 7        Intel Core i5 1.8GHz   8GB  256GB Flash Storage
# 8  Intel Core i7 8550U 1.8GHz  16GB            512GB SSD
# 9  Intel Core i5 8250U 1.6GHz   8GB            256GB SSD
#
#                             Gpu       OpSys  Weight  Price (INR)   Price (BDT)
# 0  Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832   82085.48568
# 1        Intel HD Graphics 6000       macOS  1.34kg   47895.5232   55079.85168
# 2         Intel HD Graphics 620       No OS  1.86kg   30636.0000   35231.40000
# 3            AMD Radeon Pro 455       macOS  1.83kg  135195.3360  155474.63640
# 4  Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080  110510.17920
# 5                 AMD Radeon R5  Windows 10   2.1kg   21312.0000   24508.80000
# 6       Intel Iris Pro Graphics    Mac OS X  2.04kg  114017.6016  131120.24180
# 7        Intel HD Graphics 6000       macOS  1.34kg   61735.5360   70995.86640
# 8          Nvidia GeForce MX150  Windows 10   1.3kg   79653.6000   91601.64000
# 9        Intel UHD Graphics 620  Windows 10   1.6kg   41025.6000   47179.44000

# %%
#PreProcessing & Data Cleaning
df.drop(['Price (INR)'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price (BDT)
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   82085.48568
# 1        Intel HD Graphics 6000  macOS  1.34kg   55079.85168
# 2         Intel HD Graphics 620  No OS  1.86kg   35231.40000
# 3            AMD Radeon Pro 455  macOS  1.83kg  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  110510.17920

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price (BDT)       1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   Price (BDT)
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   82085.48568
# 1           Intel HD Graphics 6000       macOS  1.34kg   55079.85168
# 2            Intel HD Graphics 620       No OS  1.86kg   35231.40000
# 3               AMD Radeon Pro 455       macOS  1.83kg  155474.63640
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  110510.17920
# ...                            ...         ...     ...           ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   39091.53600
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   91846.72800
# 1300             Intel HD Graphics  Windows 10   1.5kg   14031.28800
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   46811.80800
# 1302             Intel HD Graphics  Windows 10   2.2kg   22609.36800
#
# [1303 rows x 11 columns]

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.rename(columns={'Ram': 'RAM (GB)', 'Weight': 'Weight (KG)'}, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu RAM (GB)               Memory  \
# 0        Intel Core i5 2.3GHz        8            128GB SSD
# 1        Intel Core i5 1.8GHz        8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz        8            256GB SSD
# 3        Intel Core i7 2.7GHz       16            512GB SSD
# 4        Intel Core i5 3.1GHz        8            256GB SSD
#
#                             Gpu  OpSys Weight (KG)   Price (BDT)
# 0  Intel Iris Plus Graphics 640  macOS        1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS        1.34   55079.85168
# 2         Intel HD Graphics 620  No OS        1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS        1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS        1.37  110510.17920

# %%
df['RAM (GB)'] = df['RAM (GB)'].astype('int32')
df['Weight (KG)'] = df['Weight (KG)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   RAM (GB)          1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight (KG)       1303 non-null   float32
#  10  Price (BDT)       1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price (BDT)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price (BDT)', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Company'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['TypeName'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x = df['Inches'], y= df['Price (BDT)'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price (BDT)'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(10)
# Out:
#      Company   TypeName  Inches                  ScreenResolution  \
# 92        HP   Notebook    13.3                 Full HD 1920x1080
# 922       HP  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 1120    Vero   Notebook    13.3                 Full HD 1920x1080
# 1170      HP   Notebook    15.6                 Full HD 1920x1080
# 362   Lenovo   Notebook    17.3                          1600x900
# 539   Lenovo   Notebook    14.0       IPS Panel Full HD 1920x1080
# 295   Lenovo     Gaming    15.6       IPS Panel Full HD 1920x1080
# 675      MSI     Gaming    15.6                 Full HD 1920x1080
# 618      MSI     Gaming    15.6                 Full HD 1920x1080
# 1183    Acer   Notebook    15.6                          1366x768
#
#                                      Cpu  RAM (GB)                Memory  \
# 92            Intel Core i7 8550U 1.8GHz        16             512GB SSD
# 922           Intel Core i7 7500U 2.7GHz         8             256GB SSD
# 1120         Intel Atom X5-Z8350 1.44GHz         4    32GB Flash Storage
# 1170          Intel Core i7 6500U 2.5GHz         8             256GB SSD
# 362           Intel Core i5 7200U 2.5GHz         6  128GB SSD +  1TB HDD
# 539           Intel Core i7 7500U 2.7GHz         8             256GB SSD
# 295          Intel Core i7 7700HQ 2.8GHz         8               1TB HDD
# 675          Intel Core i7 7700HQ 2.8GHz        16  256GB SSD +  1TB HDD
# 618          Intel Core i7 7700HQ 2.8GHz        16  256GB SSD +  1TB HDD
# 1183  Intel Celeron Dual Core N3350 2GHz         4             500GB HDD
#
#                            Gpu       OpSys  Weight (KG)  Price (BDT)  \
# 92      Intel UHD Graphics 620  Windows 10         1.49   73342.5840
# 922      Intel HD Graphics 620  Windows 10         1.39   70401.5280
# 1120     Intel HD Graphics 400  Windows 10         1.35   12009.3120
# 1170     Intel HD Graphics 520  Windows 10         1.96   41603.6880
# 362   Nvidia GeForce GTX 940MX  Windows 10         2.80   44054.5680
# 539       Nvidia GeForce 940MX  Windows 10         1.87   52632.6480
# 295    Nvidia GeForce GTX 1060  Windows 10         3.20   79592.3280
# 675    Nvidia GeForce GTX 1050  Windows 10         2.40   79285.9680
# 618    Nvidia GeForce GTX 1070  Windows 10         2.94  138956.3179
# 1183     Intel HD Graphics 500  Windows 10         2.10   20403.5760
#
#       Touchscreen
# 92              0
# 922             1
# 1120            0
# 1170            0
# 362             0
# 539             0
# 295             0
# 675             0
# 618             0
# 1183            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM (GB)               Memory  \
# 0        Intel Core i5 2.3GHz         8            128GB SSD
# 1        Intel Core i5 1.8GHz         8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz         8            256GB SSD
# 3        Intel Core i7 2.7GHz        16            512GB SSD
# 4        Intel Core i5 3.1GHz         8            256GB SSD
#
#                             Gpu  OpSys  Weight (KG)   Price (BDT)  \
# 0  Intel Iris Plus Graphics 640  macOS         1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS         1.34   55079.85168
# 2         Intel HD Graphics 620  No OS         1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS         1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS         1.37  110510.17920
#
#    Touchscreen  IPS
# 0            0    1
# 1            0    0
# 2            0    0
# 3            0    1
# 4            0    1

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['IPS'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
new = df['ScreenResolution'].str.split('x', n=1, expand= True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM (GB)               Memory  \
# 0        Intel Core i5 2.3GHz         8            128GB SSD
# 1        Intel Core i5 1.8GHz         8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz         8            256GB SSD
# 3        Intel Core i7 2.7GHz        16            512GB SSD
# 4        Intel Core i5 3.1GHz         8            256GB SSD
#
#                             Gpu  OpSys  Weight (KG)   Price (BDT)  \
# 0  Intel Iris Plus Graphics 640  macOS         1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS         1.34   55079.85168
# 2         Intel HD Graphics 620  No OS         1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS         1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS         1.37  110510.17920
#
#    Touchscreen  IPS                          X_res Y_res
# 0            0    1  IPS Panel Retina Display 2560  1600
# 1            0    0                           1440   900
# 2            0    0                   Full HD 1920  1080
# 3            0    1  IPS Panel Retina Display 2880  1800
# 4            0    1  IPS Panel Retina Display 2560  1600

# %%
#regular_expression
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM (GB)               Memory  \
# 0        Intel Core i5 2.3GHz         8            128GB SSD
# 1        Intel Core i5 1.8GHz         8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz         8            256GB SSD
# 3        Intel Core i7 2.7GHz        16            512GB SSD
# 4        Intel Core i5 3.1GHz         8            256GB SSD
#
#                             Gpu  OpSys  Weight (KG)   Price (BDT)  \
# 0  Intel Iris Plus Graphics 640  macOS         1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS         1.34   55079.85168
# 2         Intel HD Graphics 620  No OS         1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS         1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS         1.37  110510.17920
#
#    Touchscreen  IPS X_res Y_res
# 0            0    1  2560  1600
# 1            0    0  1440   900
# 2            0    0  1920  1080
# 3            0    1  2880  1800
# 4            0    1  2560  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   RAM (GB)          1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight (KG)       1303 non-null   float32
#  10  Price (BDT)       1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
df['X_res']= df['X_res'].astype('int')
df['Y_res']= df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   RAM (GB)          1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight (KG)       1303 non-null   float32
#  10  Price (BDT)       1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %%
df.corr()
# Out:
#                Inches  RAM (GB)  Weight (KG)  Price (BDT)  Touchscreen  \
# Inches       1.000000  0.237993     0.827631     0.068197    -0.361735
# RAM (GB)     0.237993  1.000000     0.383874     0.743007     0.116984
# Weight (KG)  0.827631  0.383874     1.000000     0.210370    -0.294620
# Price (BDT)  0.068197  0.743007     0.210370     1.000000     0.191226
# Touchscreen -0.361735  0.116984    -0.294620     0.191226     1.000000
# IPS         -0.114804  0.206623     0.016967     0.252208     0.150512
# X_res       -0.071245  0.433121    -0.032880     0.556529     0.351066
# Y_res       -0.095404  0.424437    -0.053846     0.552809     0.357930
#
#                   IPS     X_res     Y_res
# Inches      -0.114804 -0.071245 -0.095404
# RAM (GB)     0.206623  0.433121  0.424437
# Weight (KG)  0.016967 -0.032880 -0.053846
# Price (BDT)  0.252208  0.556529  0.552809
# Touchscreen  0.150512  0.351066  0.357930
# IPS          1.000000  0.281457  0.289030
# X_res        0.281457  1.000000  0.994219
# Y_res        0.289030  0.994219  1.000000

# %%
df.corr()['Price (BDT)']
# Out:
# Inches         0.068197
# RAM (GB)       0.743007
# Weight (KG)    0.210370
# Price (BDT)    1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price (BDT), dtype: float64

# %%
df['ppi'] = ((((df['X_res']**2) + (df['Y_res']**2))**.5) / df['Inches']).astype('float')

# %%
df.corr()['Price (BDT)']
# Out:
# Inches         0.068197
# RAM (GB)       0.743007
# Weight (KG)    0.210370
# Price (BDT)    1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price (BDT), dtype: float64

# %%
df.drop(columns = ['ScreenResolution'], inplace= True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  RAM (GB)  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz         8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz         8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz         8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz        16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz         8
#
#                 Memory                           Gpu  OpSys  Weight (KG)  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS         1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS         1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS         1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS         1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS         1.37
#
#     Price (BDT)  Touchscreen  IPS  X_res  Y_res         ppi
# 0   82085.48568            0    1   2560   1600  226.983005
# 1   55079.85168            0    0   1440    900  127.677940
# 2   35231.40000            0    0   1920   1080  141.211998
# 3  155474.63640            0    1   2880   1800  220.534624
# 4  110510.17920            0    1   2560   1600  226.983005

# %%
df.drop(columns = ['Inches', 'X_res', 'Y_res'], inplace= True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  RAM (GB)  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz         8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz         8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz         8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz        16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz         8
#
#                 Memory                           Gpu  OpSys  Weight (KG)  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS         1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS         1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS         1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS         1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS         1.37
#
#     Price (BDT)  Touchscreen  IPS         ppi
# 0   82085.48568            0    1  226.983005
# 1   55079.85168            0    0  127.677940
# 2   35231.40000            0    0  141.211998
# 3  155474.63640            0    1  220.534624
# 4  110510.17920            0    1  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  RAM (GB)  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz         8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz         8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz         8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz        16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz         8
#
#                 Memory                           Gpu  OpSys  Weight (KG)  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS         1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS         1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS         1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS         1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS         1.37
#
#     Price (BDT)  Touchscreen  IPS         ppi       Cpu Name
# 0   82085.48568            0    1  226.983005  Intel Core i5
# 1   55079.85168            0    0  127.677940  Intel Core i5
# 2   35231.40000            0    0  141.211998  Intel Core i5
# 3  155474.63640            0    1  220.534624  Intel Core i7
# 4  110510.17920            0    1  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(10)
# Out:
#      Company  TypeName                                   Cpu  RAM (GB)  \
# 841     Dell    Gaming           Intel Core i7 7700HQ 2.8GHz        32
# 1088      HP  Notebook  Intel Pentium Dual Core 4405Y 1.5GHz         4
# 1006      HP  Notebook            Intel Core i5 7200U 2.5GHz         4
# 633   Lenovo  Notebook              Intel Core i3 6006U 2GHz         4
# 225     Acer  Notebook            Intel Core i7 7500U 2.7GHz         8
# 1233     MSI    Gaming           Intel Core i7 7700HQ 2.8GHz        16
# 884     Dell  Notebook  Intel Pentium Quad Core N3710 1.6GHz         4
# 982   Lenovo  Notebook           AMD A12-Series 9720P 3.6GHz         6
# 1077     MSI    Gaming           Intel Core i7 7700HQ 2.8GHz        16
# 584     Dell   Netbook  Intel Celeron Dual Core N3060 1.6GHz         4
#
#                     Memory                      Gpu       OpSys  Weight (KG)  \
# 841   512GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10         4.42
# 1088    32GB Flash Storage    Intel HD Graphics 515   Chrome OS         1.29
# 1006             256GB SSD    Intel HD Graphics 620  Windows 10         1.95
# 633                1TB HDD     Nvidia GeForce 920MX  Windows 10         2.20
# 225              256GB SSD     Nvidia GeForce 940MX  Windows 10         2.20
# 1233  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10         2.70
# 884              500GB HDD        Intel HD Graphics  Windows 10         2.20
# 982              256GB SSD           AMD Radeon 530  Windows 10         2.20
# 1077  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10         3.78
# 584     16GB Flash Storage    Intel HD Graphics 400   Chrome OS         1.26
#
#       Price (BDT)  Touchscreen  IPS         ppi              Cpu Name  \
# 841   188282.1161            0    1  127.335675         Intel Core i7
# 1088   37682.2800            0    0  276.053530    Intel Pentium Dual
# 1006   73832.7600            0    0  157.350512         Intel Core i5
# 633    35476.4880            0    0  141.211998         Intel Core i3
# 225    50978.3040            0    0  141.211998         Intel Core i7
# 1233   97912.6560            0    0  127.335675         Intel Core i7
# 884    22609.3680            0    0  100.454670    Intel Pentium Quad
# 982    33638.3280            0    0  141.211998  AMD A12-Series 9720P
# 1077  153118.7280            0    0  127.335675         Intel Core i7
# 584    18075.2400            0    0  135.094211    Intel Celeron Dual
#
#                   Cpu Brand
# 841           Intel Core i7
# 1088  Other Intel Processor
# 1006          Intel Core i5
# 633           Intel Core i3
# 225           Intel Core i7
# 1233          Intel Core i7
# 884   Other Intel Processor
# 982           AMD Processor
# 1077          Intel Core i7
# 584   Other Intel Processor

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Cpu Brand'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns=['Cpu', 'Cpu Name'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)               Memory  \
# 0   Apple  Ultrabook         8            128GB SSD
# 1   Apple  Ultrabook         8  128GB Flash Storage
# 2      HP   Notebook         8            256GB SSD
# 3   Apple  Ultrabook        16            512GB SSD
# 4   Apple  Ultrabook         8            256GB SSD
#
#                             Gpu  OpSys  Weight (KG)   Price (BDT)  \
# 0  Intel Iris Plus Graphics 640  macOS         1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS         1.34   55079.85168
# 2         Intel HD Graphics 620  No OS         1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS         1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS         1.37  110510.17920
#
#    Touchscreen  IPS         ppi      Cpu Brand
# 0            0    1  226.983005  Intel Core i5
# 1            0    0  127.677940  Intel Core i5
# 2            0    0  141.211998  Intel Core i5
# 3            0    1  220.534624  Intel Core i7
# 4            0    1  226.983005  Intel Core i5

# %%
df['RAM (GB)'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['RAM (GB)'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\abidh\AppData\Local\Temp/ipykernel_11132/4023190604.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\abidh\AppData\Local\Temp/ipykernel_11132/4023190604.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)             Memory  \
# 0   Apple  Ultrabook         8            128 SSD
# 1   Apple  Ultrabook         8  128 Flash Storage
# 2      HP   Notebook         8            256 SSD
# 3   Apple  Ultrabook        16            512 SSD
# 4   Apple  Ultrabook         8            256 SSD
#
#                             Gpu  OpSys  Weight (KG)   Price (BDT)  \
# 0  Intel Iris Plus Graphics 640  macOS         1.37   82085.48568
# 1        Intel HD Graphics 6000  macOS         1.34   55079.85168
# 2         Intel HD Graphics 620  No OS         1.86   35231.40000
# 3            AMD Radeon Pro 455  macOS         1.83  155474.63640
# 4  Intel Iris Plus Graphics 650  macOS         1.37  110510.17920
#
#    Touchscreen  IPS         ppi      Cpu Brand  HDD  SSD  Hybrid  \
# 0            0    1  226.983005  Intel Core i5    0  128       0
# 1            0    0  127.677940  Intel Core i5    0    0       0
# 2            0    0  141.211998  Intel Core i5    0  256       0
# 3            0    1  220.534624  Intel Core i7    0  512       0
# 4            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.drop(columns=['Memory'], inplace=True)

# %%
df.corr()['Price (BDT)']
# Out:
# RAM (GB)         0.743007
# Weight (KG)      0.210370
# Price (BDT)      1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price (BDT), dtype: float64

# %%
df.drop(columns=['Hybrid', 'Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)                           Gpu  OpSys  \
# 0   Apple  Ultrabook         8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook         8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook         8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook        16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook         8  Intel Iris Plus Graphics 650  macOS
#
#    Weight (KG)   Price (BDT)  Touchscreen  IPS         ppi      Cpu Brand  \
# 0         1.37   82085.48568            0    1  226.983005  Intel Core i5
# 1         1.34   55079.85168            0    0  127.677940  Intel Core i5
# 2         1.86   35231.40000            0    0  141.211998  Intel Core i5
# 3         1.83  155474.63640            0    1  220.534624  Intel Core i7
# 4         1.37  110510.17920            0    1  226.983005  Intel Core i5
#
#    HDD  SSD
# 0    0  128
# 1    0    0
# 2    0  256
# 3    0  512
# 4    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      282
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 106, dtype: int64

# %%
df['Gpu Brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)                           Gpu  OpSys  \
# 0   Apple  Ultrabook         8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook         8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook         8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook        16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook         8  Intel Iris Plus Graphics 650  macOS
#
#    Weight (KG)   Price (BDT)  Touchscreen  IPS         ppi      Cpu Brand  \
# 0         1.37   82085.48568            0    1  226.983005  Intel Core i5
# 1         1.34   55079.85168            0    0  127.677940  Intel Core i5
# 2         1.86   35231.40000            0    0  141.211998  Intel Core i5
# 3         1.83  155474.63640            0    1  220.534624  Intel Core i7
# 4         1.37  110510.17920            0    1  226.983005  Intel Core i5
#
#    HDD  SSD Gpu Brand
# 0    0  128     Intel
# 1    0    0     Intel
# 2    0  256     Intel
# 3    0  512       AMD
# 4    0  256     Intel

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu Brand, dtype: int64

# %%
sns.barplot(x=df['Gpu Brand'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns=['Gpu'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)  OpSys  Weight (KG)   Price (BDT)  Touchscreen  \
# 0   Apple  Ultrabook         8  macOS         1.37   82085.48568            0
# 1   Apple  Ultrabook         8  macOS         1.34   55079.85168            0
# 2      HP   Notebook         8  No OS         1.86   35231.40000            0
# 3   Apple  Ultrabook        16  macOS         1.83  155474.63640            0
# 4   Apple  Ultrabook         8  macOS         1.37  110510.17920            0
#
#    IPS         ppi      Cpu Brand  HDD  SSD Gpu Brand
# 0    1  226.983005  Intel Core i5    0  128     Intel
# 1    0  127.677940  Intel Core i5    0    0     Intel
# 2    0  141.211998  Intel Core i5    0  256     Intel
# 3    1  220.534624  Intel Core i7    0  512       AMD
# 4    1  226.983005  Intel Core i5    0  256     Intel

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['OS'] = df['OpSys'].apply(cat_os)
# Out:
# C:\Users\abidh\AppData\Local\Temp/ipykernel_11132/3218697124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OS'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  RAM (GB)  OpSys  Weight (KG)   Price (BDT)  Touchscreen  \
# 0   Apple  Ultrabook         8  macOS         1.37   82085.48568            0
# 1   Apple  Ultrabook         8  macOS         1.34   55079.85168            0
# 2      HP   Notebook         8  No OS         1.86   35231.40000            0
# 3   Apple  Ultrabook        16  macOS         1.83  155474.63640            0
# 4   Apple  Ultrabook         8  macOS         1.37  110510.17920            0
#
#    IPS         ppi      Cpu Brand  HDD  SSD Gpu Brand                  OS
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sns.barplot(x=df['OS'], y=df['Price (BDT)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.scatterplot(x=df['Weight (KG)'], y=df['Price (BDT)'])
# Out:
# <AxesSubplot:xlabel='Weight (KG)', ylabel='Price (BDT)'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Price (BDT)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price (BDT)', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price (BDT)']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price (BDT)', ylabel='Density'>

# %%
X = df.drop(columns= ['Price (BDT)'])
y = np.log(df['Price (BDT)'])

# %%
X.head()
# Out:
#   Company   TypeName  RAM (GB)  Weight (KG)  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook         8         1.37            0    1  226.983005
# 1   Apple  Ultrabook         8         1.34            0    0  127.677940
# 2      HP   Notebook         8         1.86            0    0  141.211998
# 3   Apple  Ultrabook        16         1.83            0    1  220.534624
# 4   Apple  Ultrabook         8         1.37            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                  OS
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
y
# Out:
# 0       11.315516
# 1       10.916539
# 2       10.469693
# 3       11.954238
# 4       11.612863
#           ...
# 1298    10.573661
# 1299    11.427876
# 1300     9.549045
# 1301    10.753891
# 1302    10.026120
# Name: Price (BDT), Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .15, random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  RAM (GB)  Weight (KG)  Touchscreen  IPS  \
# 183   Toshiba            Notebook         8         2.00            0    0
# 1141      MSI              Gaming         8         2.40            0    0
# 1049     Asus             Netbook         4         1.20            0    0
# 1020     Dell  2 in 1 Convertible         4         2.08            1    1
# 878      Dell            Notebook         4         2.18            0    0
# ...       ...                 ...       ...          ...          ...  ...
# 466      Acer            Notebook         4         2.20            0    0
# 299      Asus           Ultrabook        16         1.63            0    0
# 493      Acer            Notebook         8         2.20            0    0
# 527    Lenovo            Notebook         8         2.20            0    0
# 1193    Apple           Ultrabook         8         0.92            0    1
#
#              ppi              Cpu Brand   HDD  SSD Gpu Brand  \
# 183   100.454670          Intel Core i5     0  128     Intel
# 1141  141.211998          Intel Core i7  1000  128    Nvidia
# 1049  135.094211  Other Intel Processor     0    0     Intel
# 1020  141.211998          Intel Core i3  1000    0     Intel
# 878   141.211998          Intel Core i5  1000  128    Nvidia
# ...          ...                    ...   ...  ...       ...
# 466   100.454670          Intel Core i3   500    0    Nvidia
# 299   141.211998          Intel Core i7     0  512    Nvidia
# 493   100.454670          AMD Processor  1000    0       AMD
# 527   100.454670          Intel Core i3  2000    0    Nvidia
# 1193  226.415547  Other Intel Processor     0    0     Intel
#
#                       OS
# 183              Windows
# 1141             Windows
# 1049  Others/No OS/Linux
# 1020             Windows
# 878              Windows
# ...                  ...
# 466              Windows
# 299              Windows
# 493              Windows
# 527   Others/No OS/Linux
# 1193                 Mac
#
# [1106 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448428823
# MAE 0.21017827976392617

# %% [markdown]
# ## Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031319887
# MAE 0.2092680224260018

# %% [markdown]
# ## Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945329088
# MAE 0.2111436161344351

# %% [markdown]
# ## KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8021984604417024
# MAE 0.19319716721733537

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8301756723729158
# MAE 0.18599782416569158

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8083751076463037
# MAE 0.20240854687252915

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8870703386837926
# MAE 0.15827051598428446

# %% [markdown]
# ## Extra Trees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8764441466994809
# MAE 0.16001040267661668

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7907099969563212
# MAE 0.22998756088314457

# %% [markdown]
# ## Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8814735987869279
# MAE 0.15957467810868128

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
#xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('et',et)],weights=[5,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.890233983062709
# MAE 0.15784825006418582

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5))
    
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8729137352892635
# MAE 0.1722467768965161

# %% [markdown]
# ## Exporting Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train
# Out:
#       Company            TypeName  RAM (GB)  Weight (KG)  Touchscreen  IPS  \
# 183   Toshiba            Notebook         8         2.00            0    0
# 1141      MSI              Gaming         8         2.40            0    0
# 1049     Asus             Netbook         4         1.20            0    0
# 1020     Dell  2 in 1 Convertible         4         2.08            1    1
# 878      Dell            Notebook         4         2.18            0    0
# ...       ...                 ...       ...          ...          ...  ...
# 466      Acer            Notebook         4         2.20            0    0
# 299      Asus           Ultrabook        16         1.63            0    0
# 493      Acer            Notebook         8         2.20            0    0
# 527    Lenovo            Notebook         8         2.20            0    0
# 1193    Apple           Ultrabook         8         0.92            0    1
#
#              ppi              Cpu Brand   HDD  SSD Gpu Brand  \
# 183   100.454670          Intel Core i5     0  128     Intel
# 1141  141.211998          Intel Core i7  1000  128    Nvidia
# 1049  135.094211  Other Intel Processor     0    0     Intel
# 1020  141.211998          Intel Core i3  1000    0     Intel
# 878   141.211998          Intel Core i5  1000  128    Nvidia
# ...          ...                    ...   ...  ...       ...
# 466   100.454670          Intel Core i3   500    0    Nvidia
# 299   141.211998          Intel Core i7     0  512    Nvidia
# 493   100.454670          AMD Processor  1000    0       AMD
# 527   100.454670          Intel Core i3  2000    0    Nvidia
# 1193  226.415547  Other Intel Processor     0    0     Intel
#
#                       OS
# 183              Windows
# 1141             Windows
# 1049  Others/No OS/Linux
# 1020             Windows
# 878              Windows
# ...                  ...
# 466              Windows
# 299              Windows
# 493              Windows
# 527   Others/No OS/Linux
# 1193                 Mac
#
# [1106 rows x 12 columns]
